# %% [markdown]
# # Aluno: Clésio de Araújo Gonçalves

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # 1. Normalização dos dados

# %% [markdown]
# ## 1.1 Dataset lojas

# %%
# Lendo o dataset de lojas e alterando o tipo de dados das colunas
arquivo_lojas = 'lojas.csv'
dataset_lojas = pd.read_csv(arquivo_lojas, 
dtype = {
    'Store': np.int32, 
    'StoreType': 'category',
    'Assortment': 'category',
    'CompetitionDistance': np.float32,
    'CompetitionOpenSinceMonth': np.float32,
    'CompetitionOpenSinceYear': np.float32,
    'Promo2': np.uint8,
    'Promo2SinceWeek': np.float32,
    'Promo2SinceYear': np.float32,
    'PromoInterval': 'category'
})
dataset_lojas.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
# Quantidade de linhas e colunas
dataset_lojas.shape
# Out:
# (1115, 10)

# %%
# Informações do sobre as colunas do dataset
dataset_lojas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int32
#  1   StoreType                  1115 non-null   category
#  2   Assortment                 1115 non-null   category
#  3   CompetitionDistance        1112 non-null   float32
#  4   CompetitionOpenSinceMonth  761 non-null    float32
#  5   CompetitionOpenSinceYear   761 non-null    float32
#  6   Promo2                     1115 non-null   uint8
#  7   Promo2SinceWeek            571 non-null    float32
#  8   Promo2SinceYear            571 non-null    float32
#  9   PromoInterval              571 non-null    category
# dtypes: category(3), float32(5), int32(1), uint8(1)
# memory usage: 31.0 KB

# %%
dataset_lojas.describe()
# Out:
#             Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# count  1115.00000          1112.000000                 761.000000
# mean    558.00000          5404.900879                   7.224704
# std     322.01708          7663.176758                   3.212349
# min       1.00000            20.000000                   1.000000
# 25%     279.50000           717.500000                   4.000000
# 50%     558.00000          2325.000000                   8.000000
# 75%     836.50000          6882.500000                  10.000000
# max    1115.00000         75860.000000                  12.000000
#
#        CompetitionOpenSinceYear       Promo2  Promo2SinceWeek  Promo2SinceYear
# count                761.000000  1115.000000       571.000000       571.000000
# mean                2008.668823     0.512108        23.595446      2011.763550
# std                    6.195990     0.500078        14.141984         1.674935
# min                 1900.000000     0.000000         1.000000      2009.000000
# 25%                 2006.000000     0.000000        13.000000      2011.000000
# 50%                 2010.000000     1.000000        22.000000      2012.000000
# 75%                 2013.000000     1.000000        37.000000      2013.000000
# max                 2015.000000     1.000000        50.000000      2015.000000

# %%
# Soma de valores nulos
dataset_lojas.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
# Verificando colunas afetadas quando Promo2 = 0
dataset_lojas[dataset_lojas['Promo2'] == 0].describe()
# Out:
#              Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# count   544.000000           542.000000                 396.000000
# mean    555.531250          6549.520508                   7.260101
# std     317.491536          9374.326172                   3.176739
# min       1.000000            30.000000                   1.000000
# 25%     280.250000           992.500000                   4.000000
# 50%     559.000000          2640.000000                   8.000000
# 75%     827.250000          8105.000000                  10.000000
# max    1114.000000         75860.000000                  12.000000
#
#        CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear
# count                396.000000   544.0              0.0              0.0
# mean                2009.123779     0.0              NaN              NaN
# std                    4.326814     0.0              NaN              NaN
# min                 1990.000000     0.0              NaN              NaN
# 25%                 2006.000000     0.0              NaN              NaN
# 50%                 2010.000000     0.0              NaN              NaN
# 75%                 2013.000000     0.0              NaN              NaN
# max                 2015.000000     0.0              NaN              NaN

# %%
# Ver comportamento da coluna PromoInterval quando Promo2 = 0
dataset_lojas[dataset_lojas['Promo2'] == 0].PromoInterval.unique()
# Out:
# [NaN]
# Categories (0, object): []

# %%
# preenche com a Mediana dos valores das colunas com os valores NaN
dataset_lojas['CompetitionDistance'].fillna(dataset_lojas['CompetitionDistance'].median(), inplace=True)

# Preenche com zero os valores para as seguintes colunas:
dataset_lojas['CompetitionOpenSinceMonth'].fillna(0, inplace=True)
dataset_lojas['CompetitionOpenSinceYear'].fillna(0, inplace=True)

# Se não houver promoção, as colunas Promo2SinceWeek, Promo2SinceYear e PromoInterval devem ter valores zero.
dataset_lojas['Promo2SinceWeek'].fillna(0, inplace=True)
dataset_lojas['Promo2SinceYear'].fillna(0, inplace=True)
dataset_lojas['PromoInterval'] = dataset_lojas['PromoInterval'].cat.add_categories([0]) # add categoria 0
dataset_lojas['PromoInterval'].fillna(0, inplace=True)

# %%
# Soma de valores nulos
dataset_lojas.isnull().sum()
# Out:
# Store                        0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# dtype: int64

# %%
# Converte dados categóricos para dados numericos
dataset_lojas = pd.DataFrame(pd.get_dummies(dataset_lojas, columns=["StoreType", "Assortment", "PromoInterval"]))

# %%
dataset_lojas
# Out:
#       Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0         1               1270.0                        9.0
# 1         2                570.0                       11.0
# 2         3              14130.0                       12.0
# 3         4                620.0                        9.0
# 4         5              29910.0                        4.0
# ...     ...                  ...                        ...
# 1110   1111               1900.0                        6.0
# 1111   1112               1880.0                        4.0
# 1112   1113               9260.0                        0.0
# 1113   1114                870.0                        0.0
# 1114   1115               5350.0                        0.0
#
#       CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                       2008.0       0              0.0              0.0
# 1                       2007.0       1             13.0           2010.0
# 2                       2006.0       1             14.0           2011.0
# 3                       2009.0       0              0.0              0.0
# 4                       2015.0       0              0.0              0.0
# ...                        ...     ...              ...              ...
# 1110                    2014.0       1             31.0           2013.0
# 1111                    2006.0       0              0.0              0.0
# 1112                       0.0       0              0.0              0.0
# 1113                       0.0       0              0.0              0.0
# 1114                       0.0       1             22.0           2012.0
#
#       StoreType_a  StoreType_b  StoreType_c  StoreType_d  Assortment_a  \
# 0               0            0            1            0             1
# 1               1            0            0            0             1
# 2               1            0            0            0             1
# 3               0            0            1            0             0
# 4               1            0            0            0             1
# ...           ...          ...          ...          ...           ...
# 1110            1            0            0            0             1
# 1111            0            0            1            0             0
# 1112            1            0            0            0             0
# 1113            1            0            0            0             0
# 1114            0            0            0            1             0
#
#       Assortment_b  Assortment_c  PromoInterval_Feb,May,Aug,Nov  \
# 0                0             0                              0
# 1                0             0                              0
# 2                0             0                              0
# 3                0             1                              0
# 4                0             0                              0
# ...            ...           ...                            ...
# 1110             0             0                              0
# 1111             0             1                              0
# 1112             0             1                              0
# 1113             0             1                              0
# 1114             0             1                              0
#
#       PromoInterval_Jan,Apr,Jul,Oct  PromoInterval_Mar,Jun,Sept,Dec  \
# 0                                 0                               0
# 1                                 1                               0
# 2                                 1                               0
# 3                                 0                               0
# 4                                 0                               0
# ...                             ...                             ...
# 1110                              1                               0
# 1111                              0                               0
# 1112                              0                               0
# 1113                              0                               0
# 1114                              0                               1
#
#       PromoInterval_0
# 0                   1
# 1                   0
# 2                   0
# 3                   1
# 4                   1
# ...               ...
# 1110                0
# 1111                1
# 1112                1
# 1113                1
# 1114                0
#
# [1115 rows x 18 columns]

# %% [markdown]
# ## 1.2 Dataset de treino

# %%
# Lendo o dataset de treino
arquivo_treino = 'dataset_treino.csv'
dataset_treino = pd.read_csv(arquivo_treino,
dtype = {
    'Store': np.int32, 
    'DayOfWeek': np.uint8,
    'Open': np.uint8,
    'Sales': np.int32,
    'Customers': np.int32,
    'Promo': np.uint8,
    'StateHoliday': 'category',
    'SchoolHoliday': np.uint8
}, parse_dates=['Date'])
dataset_treino.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          3 2014-12-31   2605        327     1      0            0
# 1      2          3 2014-12-31   2269        252     1      0            0
# 2      3          3 2014-12-31   3804        408     1      0            0
# 3      4          3 2014-12-31  10152       1311     1      0            0
# 4      5          3 2014-12-31   1830        217     1      0            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
# Quantidade de linhas e colunas
dataset_treino.shape
# Out:
# (780829, 9)

# %%
# Informações do sobre as colunas do dataset
dataset_treino.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780829 entries, 0 to 780828
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Store          780829 non-null  int32
#  1   DayOfWeek      780829 non-null  uint8
#  2   Date           780829 non-null  datetime64[ns]
#  3   Sales          780829 non-null  int32
#  4   Customers      780829 non-null  int32
#  5   Open           780829 non-null  uint8
#  6   Promo          780829 non-null  uint8
#  7   StateHoliday   780829 non-null  category
#  8   SchoolHoliday  780829 non-null  uint8
# dtypes: category(1), datetime64[ns](1), int32(3), uint8(4)
# memory usage: 18.6 MB

# %%
# Quebra a data em dia, mês e ano. E exclui a coluna Date
dataset_treino['Day']=dataset_treino.Date.dt.day
dataset_treino['Month']=dataset_treino.Date.dt.month
dataset_treino['Year']=dataset_treino.Date.dt.year
dataset_treino['WeekOfYear'] = dataset_treino.Date.dt.weekofyear
dataset_treino.drop(['Date'], axis=1, inplace=True)

# %%
# StateHoliday não está padronizada no dataset de teste e treinamento (não possui o tipo C). 
# Então resolvi mapear entre ser ou não feriado
dataset_treino['StateHoliday'] = dataset_treino['StateHoliday'].map({"0": 0, "a": 1, "b": 1, "c": 1})

# %%
# Conversão de tipos de dados para melhor uso da memória
dataset_treino.StateHoliday = dataset_treino.StateHoliday.astype(np.uint8)
dataset_treino.Day = dataset_treino.Day.astype(np.uint8)
dataset_treino.Month = dataset_treino.Month.astype(np.uint8)
dataset_treino.Year = dataset_treino.Year.astype(np.int32)

# %%
# Soma de valores nulos
dataset_treino.isnull().sum()
# Out:
# Store            0
# DayOfWeek        0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# Day              0
# Month            0
# Year             0
# WeekOfYear       0
# dtype: int64

# %%
# Quantidade de lojas fechadas e sem vendas
dataset_treino[(dataset_treino.Open == 0) & (dataset_treino.Sales == 0)]
# Out:
#         Store  DayOfWeek  Sales  Customers  Open  Promo  StateHoliday  \
# 2805        1          7      0          0     0      0             0
# 2806        2          7      0          0     0      0             0
# 2807        3          7      0          0     0      0             0
# 2808        4          7      0          0     0      0             0
# 2809        5          7      0          0     0      0             0
# ...       ...        ...    ...        ...   ...    ...           ...
# 780824   1111          2      0          0     0      0             1
# 780825   1112          2      0          0     0      0             1
# 780826   1113          2      0          0     0      0             1
# 780827   1114          2      0          0     0      0             1
# 780828   1115          2      0          0     0      0             1
#
#         SchoolHoliday  Day  Month  Year  WeekOfYear
# 2805                1   28     12  2014          52
# 2806                0   28     12  2014          52
# 2807                0   28     12  2014          52
# 2808                0   28     12  2014          52
# 2809                0   28     12  2014          52
# ...               ...  ...    ...   ...         ...
# 780824              1    1      1  2013           1
# 780825              1    1      1  2013           1
# 780826              1    1      1  2013           1
# 780827              1    1      1  2013           1
# 780828              1    1      1  2013           1
#
# [132469 rows x 12 columns]

# %%
# Lojas abertas com nehuma venda
dados = dataset_treino[(dataset_treino.Open != 0) & (dataset_treino.Sales == 0)]
print("Shape: ", dados.shape)
dados.head(7)
# Out:
# Shape:  (51, 12)
#         Store  DayOfWeek  Sales  Customers  Open  Promo  StateHoliday  \
# 85673     708          3      0          0     1      1             0
# 93796     357          1      0          0     1      0             0
# 103968    227          4      0          0     1      0             0
# 104480    835          4      0          0     1      0             0
# 105415    835          3      0          0     1      0             0
# 109852    548          5      0          0     1      1             0
# 110354     28          4      0          0     1      1             0
#
#         SchoolHoliday  Day  Month  Year  WeekOfYear
# 85673               0    1     10  2014          40
# 93796               0   22      9  2014          39
# 103968              0   11      9  2014          37
# 104480              0   11      9  2014          37
# 105415              0   10      9  2014          37
# 109852              1    5      9  2014          36
# 110354              0    4      9  2014          36

# %%
# Não excluí Vendas com valor 0
# Não excluí pois aumentou a taxa de erro

# ------------------------
# Retirando as lojas que não tiveram vendas e não abriram
# Só utilizarei pra treinamento as lojas abertas e que possuem vendas

# dataset_treino = dataset_treino[(dataset_treino["Open"] != 0) & (dataset_treino['Sales'] != 0)]

# %%
dataset_treino.describe()
# Out:
#                Store     DayOfWeek          Sales      Customers  \
# count  780829.000000  780829.00000  780829.000000  780829.000000
# mean      558.559818       3.99641    5742.206014     635.854196
# std       321.919437       1.99910    3852.310932     467.815283
# min         1.000000       1.00000       0.000000       0.000000
# 25%       281.000000       2.00000    3683.000000     403.000000
# 50%       558.000000       4.00000    5691.000000     611.000000
# 75%       838.000000       6.00000    7811.000000     841.000000
# max      1115.000000       7.00000   38037.000000    7388.000000
#
#                 Open          Promo   StateHoliday  SchoolHoliday  \
# count  780829.000000  780829.000000  780829.000000  780829.000000
# mean        0.830348       0.375633       0.029867       0.187542
# std         0.375327       0.484286       0.170220       0.390346
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.000000       0.000000       0.000000
# 50%         1.000000       0.000000       0.000000       0.000000
# 75%         1.000000       1.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#                  Day          Month           Year     WeekOfYear
# count  780829.000000  780829.000000  780829.000000  780829.000000
# mean       15.715629       6.400120    2013.478792      25.899536
# std         8.793741       3.446416       0.499550      15.025218
# min         1.000000       1.000000    2013.000000       1.000000
# 25%         8.000000       3.000000    2013.000000      13.000000
# 50%        16.000000       6.000000    2013.000000      25.000000
# 75%        23.000000       9.000000    2014.000000      39.000000
# max        31.000000      12.000000    2014.000000      52.000000

# %%
# Quantidade de vendas x valor das vendas
plt.figure(figsize = (16,7))
dataset_treino.Sales.hist(bins = 50)
plt.xlabel("Valor")
plt.ylabel("Quantidade")
plt.title("Distribuição das vendas")
plt.show()

# %%
# Quantidade de Vendas com valor 0 quando a loja esteja fechada
dataset_treino[dataset_treino.Open == 0].Sales.count()
# Out:
# 132469

# %%
# Correlação das colunas de treino
correlacao = pd.DataFrame(dataset_treino.loc[:, ['DayOfWeek', 'Sales', 'Customers', 'Open', 'Promo', 
                                                 'StateHoliday', 'SchoolHoliday', 'Month', 
                                                 'Year', 'Day']].corr())

# %%
# Correlação dataset de treino
# Correlação muito alta entre Sales e Customers.
# No geral, quanto mais clientes maiores as vendas
plt.figure(figsize = (16,7))
sns.heatmap(data=correlacao)
plt.show()

# %% [markdown]
# ## 1.3 Dataset de teste

# %%
# Lendo o dataset de teste
arquivo_teste = 'dataset_teste.csv'
dataset_teste = pd.read_csv(arquivo_teste,
dtype = {
    'Id': np.int32,
    'Store': np.int32, 
    'DayOfWeek': np.uint8,
    'Open': np.uint8,
    'Promo': np.uint8,
    'StateHoliday': 'category',
    'SchoolHoliday': np.uint8
}, parse_dates=['Date'])

dataset_teste.head()
# Out:
#    Id  Store  DayOfWeek       Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          5 2015-07-31     1      1            0              1
# 1   2      2          5 2015-07-31     1      1            0              1
# 2   3      3          5 2015-07-31     1      1            0              1
# 3   4      4          5 2015-07-31     1      1            0              1
# 4   5      5          5 2015-07-31     1      1            0              1

# %%
# Quantidade de linhas e colunas
dataset_teste.shape
# Out:
# (236380, 8)

# %%
# Informações do sobre as colunas do dataset
dataset_teste.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236380 entries, 0 to 236379
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Id             236380 non-null  int32
#  1   Store          236380 non-null  int32
#  2   DayOfWeek      236380 non-null  uint8
#  3   Date           236380 non-null  datetime64[ns]
#  4   Open           236380 non-null  uint8
#  5   Promo          236380 non-null  uint8
#  6   StateHoliday   236380 non-null  category
#  7   SchoolHoliday  236380 non-null  uint8
# dtypes: category(1), datetime64[ns](1), int32(2), uint8(4)
# memory usage: 4.7 MB

# %%
# Quebra a data em dia, mês e ano. E exclui a coluna Date
dataset_teste['Day'] = dataset_teste.Date.dt.day
dataset_teste['Month'] = dataset_teste.Date.dt.month
dataset_teste['Year'] = dataset_teste.Date.dt.year
dataset_teste['WeekOfYear'] = dataset_teste.Date.dt.weekofyear
dataset_teste.drop(['Date'], axis=1, inplace=True)

# %%
# StateHoliday não está padronizada no dataset de teste e treinamento (não possui o tipo C). 
# Então resolvi mapear entre ser ou não feriado
dataset_teste['StateHoliday'] = dataset_teste['StateHoliday'].map({"0": 0, "a": 1, "b": 1, "c": 1})

# %%
# Conversão de tipos de dados para melhor uso da memória
dataset_teste.StateHoliday = dataset_teste.StateHoliday.astype(np.uint8)
dataset_teste.Day = dataset_teste.Day.astype(np.uint8)
dataset_teste.Month = dataset_teste.Month.astype(np.uint8)
dataset_teste.Year = dataset_teste.Year.astype(np.int32)

# %%
# Soma de valores nulos
dataset_teste.isnull().sum()
# Out:
# Id               0
# Store            0
# DayOfWeek        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# Day              0
# Month            0
# Year             0
# WeekOfYear       0
# dtype: int64

# %%
dataset_teste.describe()
# Out:
#                   Id          Store      DayOfWeek           Open  \
# count  236380.000000  236380.000000  236380.000000  236380.000000
# mean   118190.500000     558.000000       4.004717       0.829309
# std     68237.172653     321.873326       1.991727       0.376240
# min         1.000000       1.000000       1.000000       0.000000
# 25%     59095.750000     279.000000       2.000000       1.000000
# 50%    118190.500000     558.000000       4.000000       1.000000
# 75%    177285.250000     837.000000       6.000000       1.000000
# max    236380.000000    1115.000000       7.000000       1.000000
#
#                Promo   StateHoliday  SchoolHoliday            Day  \
# count  236380.000000  236380.000000  236380.000000  236380.000000
# mean        0.400943       0.032697       0.149264      15.660377
# std         0.490091       0.177844       0.356349       8.767332
# min         0.000000       0.000000       0.000000       1.000000
# 25%         0.000000       0.000000       0.000000       8.000000
# 50%         0.000000       0.000000       0.000000      16.000000
# 75%         1.000000       0.000000       0.000000      23.000000
# max         1.000000       1.000000       1.000000      31.000000
#
#                Month      Year     WeekOfYear
# count  236380.000000  236380.0  236380.000000
# mean        4.018868    2015.0      16.070755
# std         2.004627       0.0       8.750743
# min         1.000000    2015.0       1.000000
# 25%         2.000000    2015.0       8.750000
# 50%         4.000000    2015.0      16.000000
# 75%         6.000000    2015.0      24.000000
# max         7.000000    2015.0      31.000000

# %%
# Quandtidade de lojas fechadas (por isso não exclui as vendas com valor zero no dataset_treino)
dataset_teste[dataset_teste.Open == 0].Open.count()
# Out:
# 40348

# %% [markdown]
# # 2. Merge nos conjuntos de dados

# %% [markdown]
# ## 2.1 Merge no dataset de treinamento

# %%
dataset_lojas
# Out:
#       Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0         1               1270.0                        9.0
# 1         2                570.0                       11.0
# 2         3              14130.0                       12.0
# 3         4                620.0                        9.0
# 4         5              29910.0                        4.0
# ...     ...                  ...                        ...
# 1110   1111               1900.0                        6.0
# 1111   1112               1880.0                        4.0
# 1112   1113               9260.0                        0.0
# 1113   1114                870.0                        0.0
# 1114   1115               5350.0                        0.0
#
#       CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                       2008.0       0              0.0              0.0
# 1                       2007.0       1             13.0           2010.0
# 2                       2006.0       1             14.0           2011.0
# 3                       2009.0       0              0.0              0.0
# 4                       2015.0       0              0.0              0.0
# ...                        ...     ...              ...              ...
# 1110                    2014.0       1             31.0           2013.0
# 1111                    2006.0       0              0.0              0.0
# 1112                       0.0       0              0.0              0.0
# 1113                       0.0       0              0.0              0.0
# 1114                       0.0       1             22.0           2012.0
#
#       StoreType_a  StoreType_b  StoreType_c  StoreType_d  Assortment_a  \
# 0               0            0            1            0             1
# 1               1            0            0            0             1
# 2               1            0            0            0             1
# 3               0            0            1            0             0
# 4               1            0            0            0             1
# ...           ...          ...          ...          ...           ...
# 1110            1            0            0            0             1
# 1111            0            0            1            0             0
# 1112            1            0            0            0             0
# 1113            1            0            0            0             0
# 1114            0            0            0            1             0
#
#       Assortment_b  Assortment_c  PromoInterval_Feb,May,Aug,Nov  \
# 0                0             0                              0
# 1                0             0                              0
# 2                0             0                              0
# 3                0             1                              0
# 4                0             0                              0
# ...            ...           ...                            ...
# 1110             0             0                              0
# 1111             0             1                              0
# 1112             0             1                              0
# 1113             0             1                              0
# 1114             0             1                              0
#
#       PromoInterval_Jan,Apr,Jul,Oct  PromoInterval_Mar,Jun,Sept,Dec  \
# 0                                 0                               0
# 1                                 1                               0
# 2                                 1                               0
# 3                                 0                               0
# 4                                 0                               0
# ...                             ...                             ...
# 1110                              1                               0
# 1111                              0                               0
# 1112                              0                               0
# 1113                              0                               0
# 1114                              0                               1
#
#       PromoInterval_0
# 0                   1
# 1                   0
# 2                   0
# 3                   1
# 4                   1
# ...               ...
# 1110                0
# 1111                1
# 1112                1
# 1113                1
# 1114                0
#
# [1115 rows x 18 columns]

# %%
dataset_treino
# Out:
#         Store  DayOfWeek  Sales  Customers  Open  Promo  StateHoliday  \
# 0           1          3   2605        327     1      0             0
# 1           2          3   2269        252     1      0             0
# 2           3          3   3804        408     1      0             0
# 3           4          3  10152       1311     1      0             0
# 4           5          3   1830        217     1      0             0
# ...       ...        ...    ...        ...   ...    ...           ...
# 780824   1111          2      0          0     0      0             1
# 780825   1112          2      0          0     0      0             1
# 780826   1113          2      0          0     0      0             1
# 780827   1114          2      0          0     0      0             1
# 780828   1115          2      0          0     0      0             1
#
#         SchoolHoliday  Day  Month  Year  WeekOfYear
# 0                   1   31     12  2014           1
# 1                   1   31     12  2014           1
# 2                   1   31     12  2014           1
# 3                   1   31     12  2014           1
# 4                   1   31     12  2014           1
# ...               ...  ...    ...   ...         ...
# 780824              1    1      1  2013           1
# 780825              1    1      1  2013           1
# 780826              1    1      1  2013           1
# 780827              1    1      1  2013           1
# 780828              1    1      1  2013           1
#
# [780829 rows x 12 columns]

# %%
# Merge entre dataset_lojas e dataset_treino
dataset_treino = pd.merge(dataset_treino, dataset_lojas, on='Store')

# %%
# Duração de tempo em que a competidora ficou aberta (em meses)
dataset_treino['CompetitionOpenSince'] = np.where(
    (dataset_treino.CompetitionOpenSinceYear == 0), 0,
    (12 * (dataset_treino.Year - dataset_treino.CompetitionOpenSinceYear) + 
    (dataset_treino.Month - dataset_treino.CompetitionOpenSinceMonth))
)

dataset_treino.drop(['CompetitionOpenSinceYear'], axis=1, inplace=True)
dataset_treino.drop(['CompetitionOpenSinceMonth'], axis=1, inplace=True)

# Zera a duração de tempo de CompetitionOpenSince negativa 
# (a competidora abriu em data futura da venda da loja atual)
dataset_treino.CompetitionOpenSince[dataset_treino['CompetitionOpenSince'] < 0] = 0

# %%
# Duração de tempo em que a loja participa da promoção (em meses)
dataset_treino['Promo2Since'] = np.where(
    (dataset_treino.Promo2SinceYear == 0), 0,
    (12 * (dataset_treino.Year - dataset_treino.Promo2SinceYear) + 
    (dataset_treino.WeekOfYear - dataset_treino.Promo2SinceWeek) / 4.0)
)
dataset_treino.drop(['Promo2SinceYear'], axis=1, inplace=True)
dataset_treino.drop(['Promo2SinceWeek'], axis=1, inplace=True)

# Zera a duração de tempo de Promo2Since negativa 
# (a loja começou a participar da Promo2 em data futura da venda)
dataset_treino.Promo2Since[dataset_treino['Promo2Since'] < 0] = 0

# %%
# Correlação
plt.figure(figsize = (16,10))
sns.heatmap(data=dataset_treino.corr())
plt.show()

# %% [markdown]
# ## 2.2 Merge no dataset de teste

# %%
# Merge dataset_teste e dataset_lojas
dataset_teste = pd.merge(dataset_teste, dataset_lojas, on='Store')

# %%
# Duração de tempo em que a competidora ficou aberta (em meses)
dataset_teste['CompetitionOpenSince'] = np.where(
    (dataset_teste.CompetitionOpenSinceYear == 0), 0,
    (12 * (dataset_teste.Year - dataset_teste.CompetitionOpenSinceYear) + 
    (dataset_teste.Month - dataset_teste.CompetitionOpenSinceMonth))
)

dataset_teste.drop(['CompetitionOpenSinceYear'], axis=1, inplace=True)
dataset_teste.drop(['CompetitionOpenSinceMonth'], axis=1, inplace=True)

# Zera a duração de tempo de CompetitionOpenSince negativa 
# (a competidora abriu em data futura da venda da loja atual)
dataset_teste.CompetitionOpenSince[dataset_teste['CompetitionOpenSince'] < 0] = 0

# %%
# Duração de tempo em que a loja participa da promoção (em meses)
dataset_teste['Promo2Since'] = np.where(
    (dataset_teste.Promo2SinceYear == 0), 0,
    (12 * (dataset_teste.Year - dataset_teste.Promo2SinceYear) + 
    (dataset_teste.WeekOfYear - dataset_teste.Promo2SinceWeek) / 4.0)
)
dataset_teste.drop(['Promo2SinceYear'], axis=1, inplace=True)
dataset_teste.drop(['Promo2SinceWeek'], axis=1, inplace=True)

# Zera a duração de tempo de Promo2Since negativa 
# (a loja começou a participar da Promo2 em data futura da venda)
dataset_teste.Promo2Since[dataset_teste['Promo2Since'] < 0] = 0

# %% [markdown]
# # 3. Regressão no dataset de treino

# %%
dataset_treino.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 780829 entries, 0 to 780828
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Store                           780829 non-null  int32
#  1   DayOfWeek                       780829 non-null  uint8
#  2   Sales                           780829 non-null  int32
#  3   Customers                       780829 non-null  int32
#  4   Open                            780829 non-null  uint8
#  5   Promo                           780829 non-null  uint8
#  6   StateHoliday                    780829 non-null  uint8
#  7   SchoolHoliday                   780829 non-null  uint8
#  8   Day                             780829 non-null  uint8
#  9   Month                           780829 non-null  uint8
#  10  Year                            780829 non-null  int32
#  11  WeekOfYear                      780829 non-null  int64
#  12  CompetitionDistance             780829 non-null  float32
#  13  Promo2                          780829 non-null  uint8
#  14  StoreType_a                     780829 non-null  uint8
#  15  StoreType_b                     780829 non-null  uint8
#  16  StoreType_c                     780829 non-null  uint8
#  17  StoreType_d                     780829 non-null  uint8
#  18  Assortment_a                    780829 non-null  uint8
#  19  Assortment_b                    780829 non-null  uint8
#  20  Assortment_c                    780829 non-null  uint8
#  21  PromoInterval_Feb,May,Aug,Nov   780829 non-null  uint8
#  22  PromoInterval_Jan,Apr,Jul,Oct   780829 non-null  uint8
#  23  PromoInterval_Mar,Jun,Sept,Dec  780829 non-null  uint8
#  24  PromoInterval_0                 780829 non-null  uint8
#  25  CompetitionOpenSince            780829 non-null  float32
#  26  Promo2Since                     780829 non-null  float64
# dtypes: float32(2), float64(1), int32(4), int64(1), uint8(19)
# memory usage: 49.9 MB

# %%
# Definindo os atributos para X e Y
X = dataset_treino.drop(['Sales', 'Customers'], axis = 1)
Y = dataset_treino.Sales

# %%
# Alterando o shape de Y -> Array 2D
Y = np.array(Y).reshape(-1, 1)

# %%
# Ajustando a escala
from sklearn.preprocessing import MinMaxScaler
x_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()

X = x_scaler.fit_transform(X)
Y = y_scaler.fit_transform(Y)

# %%
# Alterando o shape de Y -> Array 1D
Y = np.array(Y).reshape(-1)

# %% [markdown]
# ## 3.1 Regressão Linear: mesmo conjunto de dados

# %%
# Importando o módulo de Regressão Linear do scikit-learn e metrics
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
# Cria o modelo de regressão linear
modelo_linear = LinearRegression()

# %%
# Treinando o modelo
modelo_linear.fit(X, Y)
# Out:
# LinearRegression()

# %%
# Prevendo o Sales de X_treino
predicao_linear = modelo_linear.predict(X)

# %%
# Valores abaixo de zero recebem zero
print("Valores abaixo de zero: ", predicao_linear[predicao_linear < 0].size)
predicao_linear[predicao_linear < 0] = 0
# Out:
# Valores abaixo de zero:  69563

# %%
# Calcular o MAE (Mean Absolute Error)
print("MAE: ", np.sqrt(np.mean((Y - predicao_linear) ** 2)))
print("R2 Score: ", r2_score(Y, predicao_linear))
# Out:
# MAE:  0.06679636424906114
# R2 Score:  0.5650132264980431

# %%
# Comparando Vendas originais x Vendas previstas
plt.scatter(Y, predicao_linear)
plt.xlabel("Sales Original")
plt.ylabel("Sales Previsto")
plt.title("Sales Original x Sales Previsto")
plt.show()

# %% [markdown]
# ## 3.2 Regressão Polinomial: mesmo conjunto de dados

# %%
# Regressão Polinomial
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

degree = 2

# %%
# Treinamento do modelo polinomial
modelo_polinomial = make_pipeline(PolynomialFeatures(degree), Ridge())
modelo_polinomial.fit(X, Y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('ridge', Ridge())])

# %%
# Predição do modelo polinomial
predicao_polinominal = modelo_polinomial.predict(X)

# %%
# Valores abaixo de zero recebem zero
print("Valores abaixo de 0: ", predicao_polinominal[predicao_polinominal < 0].size)
predicao_polinominal[predicao_polinominal < 0] = 0
# Out:
# Valores abaixo de 0:  68919

# %%
print("MAE: ", np.sqrt(np.mean((Y - predicao_polinominal) ** 2)))
print("R2 Score: ", r2_score(Y, predicao_polinominal))
# Out:
# MAE:  0.06265504484035352
# R2 Score:  0.6172788231981322

# %%
# Comparando Vendas originais x Vendas previstas
plt.scatter(Y, predicao_polinominal)
plt.xlabel("Sales Original")
plt.ylabel("Sales Previsto")
plt.title("Sales Original x Sales Previsto")
plt.show()

# %% [markdown]
# ## 3.3 Random Forest: mesmo conjunto de dados

# %%
# Treinamento da Random Forest
from sklearn.ensemble import RandomForestRegressor

regressor_rf = RandomForestRegressor(random_state=0, n_jobs=-1)
regressor_rf.fit(X, Y)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=0)

# %%
# Predição
predicao_rf = regressor_rf.predict(X)

# %%
# Valores abaixo de zero recebem zero
print("Valores abaixo de 0: ", predicao_rf[predicao_rf < 0].size)
predicao_rf[predicao_rf < 0] = 0
# Out:
# Valores abaixo de 0:  0

# %%
print("MAE: ", np.sqrt(np.mean((Y - predicao_rf) ** 2)))
print("R2 Score: ", r2_score(Y, predicao_rf))
# Out:
# MAE:  0.008433029553184541
# R2 Score:  0.9930667374303285

# %%
# Comparando Vendas originais x Vendas previstas
plt.scatter(Y, predicao_rf)
plt.xlabel("Sales Original")
plt.ylabel("Sales Previsto")
plt.title("Sales Original x Sales Previsto")
plt.show()

# %% [markdown]
# # 4. Predição no dataset de teste e publicação do resultado

# %%
dataset_teste.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236380 entries, 0 to 236379
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Id                              236380 non-null  int32
#  1   Store                           236380 non-null  int32
#  2   DayOfWeek                       236380 non-null  uint8
#  3   Open                            236380 non-null  uint8
#  4   Promo                           236380 non-null  uint8
#  5   StateHoliday                    236380 non-null  uint8
#  6   SchoolHoliday                   236380 non-null  uint8
#  7   Day                             236380 non-null  uint8
#  8   Month                           236380 non-null  uint8
#  9   Year                            236380 non-null  int32
#  10  WeekOfYear                      236380 non-null  int64
#  11  CompetitionDistance             236380 non-null  float32
#  12  Promo2                          236380 non-null  uint8
#  13  StoreType_a                     236380 non-null  uint8
#  14  StoreType_b                     236380 non-null  uint8
#  15  StoreType_c                     236380 non-null  uint8
#  16  StoreType_d                     236380 non-null  uint8
#  17  Assortment_a                    236380 non-null  uint8
#  18  Assortment_b                    236380 non-null  uint8
#  19  Assortment_c                    236380 non-null  uint8
#  20  PromoInterval_Feb,May,Aug,Nov   236380 non-null  uint8
#  21  PromoInterval_Jan,Apr,Jul,Oct   236380 non-null  uint8
#  22  PromoInterval_Mar,Jun,Sept,Dec  236380 non-null  uint8
#  23  PromoInterval_0                 236380 non-null  uint8
#  24  CompetitionOpenSince            236380 non-null  float32
#  25  Promo2Since                     236380 non-null  float64
# dtypes: float32(2), float64(1), int32(3), int64(1), uint8(19)
# memory usage: 14.2 MB

# %%
# Definindo atributos para X_teste
X2 = dataset_teste.drop(['Id'], axis = 1)

# %%
# Ajustando a escala
X2 = x_scaler.fit_transform(X2)

# %%
X.shape
# Out:
# (780829, 25)

# %%
X2.shape
# Out:
# (236380, 25)

# %%
# Predição para o dataset_teste utilizando o modelo Random Forest
# Não é necessário fazer o fit, pois o fit foi feito em X (database_treino)
# predicao_polinominal_submissao = modelo_polinomial.predict(X2) -> antigo
predicao_rf_submissao = regressor_rf.predict(X2)

# %%
# Valores abaixo de 0 recebem 0
print("Valores abaixo de 0: ", predicao_rf_submissao[predicao_rf_submissao < 0].size)
predicao_rf_submissao[predicao_rf_submissao < 0] = 0
# Out:
# Valores abaixo de 0:  0

# %%
# Alterarando o shape para o inverse transform -> Array 2D
predicao_rf_submissao = np.array(predicao_rf_submissao).reshape(-1, 1)

# Inverse transform nos dados da predição da Random Forest
predicao_rf_submissao = y_scaler.inverse_transform(predicao_rf_submissao)

# Alterarando o shape para o data Frame -> -> Array 1D
predicao_rf_submissao = np.array(predicao_rf_submissao).reshape(-1)

# %%
# Juntanto a predição em um data frame
resultado_teste = pd.DataFrame({'Id': dataset_teste['Id'], 'Sales': predicao_rf_submissao})
resultado_teste.head(20)
# Out:
#        Id     Sales
# 0       1   9613.30
# 1    1116   9490.80
# 2    2231   9506.68
# 3    3346   9676.27
# 4    4461  10749.96
# 5    5576      0.00
# 6    6691   6497.04
# 7    7806   4550.36
# 8    8921   7745.12
# 9   10036   7538.03
# 10  11151   7585.32
# 11  12266   4717.80
# 12  13381      0.00
# 13  14496   7643.91
# 14  15611   7209.00
# 15  16726   7207.02
# 16  17841   7256.52
# 17  18956   7455.09
# 18  20071   8567.37
# 19  21186      0.00

# %%
# Ordenando os dados do resultado da predição do dataset de teste
resultado_teste = resultado_teste.sort_values(by = ['Id'])

# %%
# Exportando os resultados para o CSV
resultado_teste.to_csv("Predicao_Clesio_de_Araujo_Goncalves_v3.csv", header = True, index = False)
